# %% [markdown]
# <a href="https://colab.research.google.com/github/Qitaa/PCVK_Genap_2022/blob/main/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Buatlah fungsi dilasi serta tampilkan hasil dilasi pada citra dengan Structuring Element Dilasi (SED) berbentuk square 3 x 3 tanpa menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
img = cv.imread('/content/drive/MyDrive/Images/j.png')

kernel = np.ones((3,3), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f65e44a25d0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %% [markdown]
#  Buatlah program implementasi operasi dilasi Structuring Element Dilasi (SED)
# berbentuk square 3 x 3 dengan menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
img1= cv.imread('/content/drive/MyDrive/Images/j.png', 0)

m,n= img1.shape 
plt.imshow(img1, cmap="gray")
k=5
SE= np.ones((k,k), dtype=np.uint8)
constant= (k-1)//2

imgErode= np.zeros((m,n), dtype=np.uint8)
for i in range(constant, m-constant):
  for j in range(constant,n-constant):
    temp= img1[i-constant:i+constant+1, j-constant:j+constant+1]
    product= temp*SE
    imgErode[i,j]= np.min(product)
plt.subplot(121), plt.imshow(img1, cmap ="gray"), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(imgErode, cmap="gray"), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f65e3ebe410>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %% [markdown]
#  Buatlah program implementasi operasi dilasi Structuring Element Dilasi (SED) berbentuk square 3 x 3 dengan menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
kernel = np.ones((3,3), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f65e3dc40d0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %% [markdown]
# Buatlah program implementasi operasi dilasi Structuring Element Erosi (SE) berbentuk square 5 x 5 dengan menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Citra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f65e3eec2d0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Erosi'))

# %% [markdown]
# Buatlah program implementasi operasi closing dengan Structuring Element berbentuk square 9 x 9 tanpa dan dengan menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar jpng)

# %%
kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Citra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f65e3de53d0>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Opening'))

# %% [markdown]
# Buatlah program implementasi operasi closing dengan Structuring Element berbentuk square 9 x 9 tanpa dan dengan menggunakan library morphology dari openCV, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png)

# %%
kernel = np.ones((9,9), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Citra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f65e3b24250>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Closing'))

# %% [markdown]
# Buatlah program implementasi operasi dilasi dengan Structuring Element berbentuk Cross 3 x 3 dan 5 x 5, sehingga menghasilkan tampilan seperti di bawah ini: (Gunakan gambar j.png

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (3, 3))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 3x3')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f65e3a7e050>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 3x3'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_CROSS, (5, 5))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Dilasi 5x5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f65e39caf50>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Dilasi 5x5'))

# %% [markdown]
# Buatlah program implementasi operasi dilasi dengan Structuring Element berbentuk Circular 7 x 7 dan 9 x 9, sehingga menghasilkan tampilan seperti di bawah ini:

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (7, 7))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 7x7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f65e392a150>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Circular 7x7'))

# %%
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (9, 9))
cross3 = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(cross3), plt.title('Citra Hasil Circular 9x9')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f65e3805910>,
# ...
#  Text(0.5, 1.0, 'Citra Hasil Circular 9x9'))
